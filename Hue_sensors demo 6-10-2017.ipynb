# %%
from hue_sensors import (
    load_url, print_json, parse_hue_api_response, get_response_from_url,
    save_response)

# %% [markdown]
# First load the URL, in my case I am loading from a json doc on my desktop. This keeps my API key secret.

# %%
filename = '/Users/robincole/Desktop/Hue_url.json'
URL = load_url(filename)    # base URL of the remote, ending /sensors

# %% [markdown]
# URL = 'http://192.168.0.3/api/my_key/sensors'

# %% [markdown]
# Fetch the response (raw data) from this URL

# %%
response = get_response_from_url(URL)

# %% [markdown]
# Pretty print the json

# %%
print_json(response)
# Out:
# {'1': {'config': {'configured': True,
#                   'on': True,
#                   'sunriseoffset': 30,
#                   'sunsetoffset': -30},
#        'manufacturername': 'Philips',
#        'modelid': 'PHDL00',
#        'name': 'Daylight',
#        'state': {'daylight': True, 'lastupdated': '2017-10-06T06:40:00'},
#        'swversion': '1.0',
#        'type': 'Daylight'},
#  '10': {'config': {'alert': 'none',
#                    'battery': 100,
#                    'ledindication': False,
#                    'on': True,
#                    'pending': [],
#                    'reachable': True,
#                    'tholddark': 12853,
#                    'tholdoffset': 7000,
#                    'usertest': False},
#         'manufacturername': 'Philips',
#         'modelid': 'SML001',
#         'name': 'Hue ambient light sensor 2',
#         'state': {'dark': True,
#                   'daylight': False,
#                   'lastupdated': '2017-10-06T06:55:49',
#                   'lightlevel': 10014},
#         'swupdate': {'lastinstall': None, 'state': 'noupdates'},
#         'swversion': '6.1.0.18912',
#         'type': 'ZLLLightLevel',
#         'uniqueid': '00:17:88:01:02:00:b5:ce-02-0400'},
#  '11': {'config': {'on': True, 'reachable': True},
#         'manufacturername': 'Philips',
#         'modelid': 'PHA_STATE',
#         'name': 'MotionSensor 9.Companion',
#         'recycle': True,
#         'state': {'lastupdated': '2017-10-06T06:00:54', 'status': 0},
#         'swversion': '1.0',
#         'type': 'CLIPGenericStatus',
#         'uniqueid': 'MotionSensor 9.Companion'},
#  '12': {'config': {'on': True, 'reachable': True},
#         'manufacturername': 'Philips',
#         'modelid': 'HA_GEOFENCE',
#         'name': 'Robins iPhone',
#         'recycle': False,
#         'state': {'lastupdated': '2017-10-05T20:43:04', 'presence': True},
#         'swversion': 'A_1',
#         'type': 'Geofence',
#         'uniqueid': 'L_02_IYwHM'},
#  '13': {'config': {'on': True, 'reachable': True},
#         'manufacturername': 'Philips',
#         'modelid': 'HOMEAWAY',
#         'name': 'HomeAway',
#         'recycle': False,
#         'state': {'lastupdated': '2017-10-05T20:43:04', 'presence': True},
#         'swversion': 'A_1',
#         'type': 'CLIPPresence',
#         'uniqueid': 'L_01_9rQ8A'},
#  '14': {'config': {'alert': 'none',
#                    'battery': 100,
#                    'ledindication': False,
#                    'on': True,
#                    'pending': [],
#                    'reachable': True,
#                    'usertest': False},
#         'manufacturername': 'Philips',
#         'modelid': 'SML001',
#         'name': 'Hue temperature sensor 3',
#         'state': {'lastupdated': '2017-10-06T06:57:15', 'temperature': 2054},
#         'swupdate': {'lastinstall': None, 'state': 'noupdates'},
#         'swversion': '6.1.0.18912',
#         'type': 'ZLLTemperature',
#         'uniqueid': '00:17:88:01:02:01:aa:9c-02-0402'},
#  '15': {'config': {'alert': 'none',
#                    'battery': 100,
#                    'ledindication': False,
#                    'on': True,
#                    'pending': [],
#                    'reachable': True,
#                    'sensitivity': 2,
#                    'sensitivitymax': 2,
#                    'usertest': False},
#         'manufacturername': 'Philips',
#         'modelid': 'SML001',
#         'name': 'Living room sensor',
#         'state': {'lastupdated': '2017-10-06T06:57:26', 'presence': False},
#         'swupdate': {'lastinstall': None, 'state': 'noupdates'},
#         'swversion': '6.1.0.18912',
#         'type': 'ZLLPresence',
#         'uniqueid': '00:17:88:01:02:01:aa:9c-02-0406'},
#  '16': {'config': {'alert': 'none',
#                    'battery': 100,
#                    'ledindication': False,
#                    'on': True,
#                    'pending': [],
#                    'reachable': True,
#                    'tholddark': 16000,
#                    'tholdoffset': 7000,
#                    'usertest': False},
#         'manufacturername': 'Philips',
#         'modelid': 'SML001',
#         'name': 'Hue ambient light sensor 3',
#         'state': {'dark': True,
#                   'daylight': False,
#                   'lastupdated': '2017-10-06T06:57:27',
#                   'lightlevel': 14189},
#         'swupdate': {'lastinstall': None, 'state': 'noupdates'},
#         'swversion': '6.1.0.18912',
#         'type': 'ZLLLightLevel',
#         'uniqueid': '00:17:88:01:02:01:aa:9c-02-0400'},
#  '18': {'config': {'on': True, 'reachable': True},
#         'manufacturername': 'Philips',
#         'modelid': 'PHA_STATE',
#         'name': 'MotionSensor 15.Companion',
#         'recycle': True,
#         'state': {'lastupdated': '2017-10-06T06:57:26', 'status': 0},
#         'swversion': '1.0',
#         'type': 'CLIPGenericStatus',
#         'uniqueid': 'MotionSensor 15.Companion'},
#  '2': {'config': {'battery': 100, 'on': True, 'pending': [], 'reachable': True},
#        'manufacturername': 'Philips',
#        'modelid': 'RWL021',
#        'name': 'Remote bedroom',
#        'state': {'buttonevent': 4002, 'lastupdated': '2017-10-06T06:00:40'},
#        'swupdate': {'lastinstall': None, 'state': 'noupdates'},
#        'swversion': '5.45.1.16265',
#        'type': 'ZLLSwitch',
#        'uniqueid': '00:17:88:01:10:3e:3a:dc-02-fc00'},
#  '20': {'config': {'battery': 100,
#                    'on': True,
#                    'pending': [],
#                    'reachable': True},
#         'manufacturername': 'Philips',
#         'modelid': 'RWL021',
#         'name': 'Living room remote',
#         'state': {'buttonevent': 4003, 'lastupdated': '2017-10-05T21:35:48'},
#         'swupdate': {'lastinstall': None, 'state': 'noupdates'},
#         'swversion': '5.45.1.17846',
#         'type': 'ZLLSwitch',
#         'uniqueid': '00:17:88:01:02:e2:47:1e-02-fc00'},
#  '21': {'config': {'on': True, 'reachable': True},
#         'manufacturername': 'Philips',
#         'modelid': 'PHWA01',
#         'name': 'Dimmer Switch 20 SceneCycle',
#         'recycle': True,
#         'state': {'lastupdated': '2017-10-05T21:35:45', 'status': 0},
#         'swversion': '1.0',
#         'type': 'CLIPGenericStatus',
#         'uniqueid': 'WA0001'},
#  '22': {'config': {'battery': 100,
#                    'on': True,
#                    'pending': [],
#                    'reachable': True},
#         'manufacturername': 'Philips',
#         'modelid': 'RWL021',
#         'name': 'Hall remote',
#         'state': {'buttonevent': 1003, 'lastupdated': '2017-10-04T06:04:54'},
#         'swupdate': {'lastinstall': None, 'state': 'noupdates'},
#         'swversion': '5.45.1.17846',
#         'type': 'ZLLSwitch',
#         'uniqueid': '00:17:88:01:02:c0:e1:9c-02-fc00'},
#  '23': {'config': {'on': True, 'reachable': True},
#         'manufacturername': 'Philips',
#         'modelid': 'PHWA01',
#         'name': 'Dimmer Switch 22 SceneCycle',
#         'recycle': True,
#         'state': {'lastupdated': '2017-10-04T06:04:52', 'status': 1},
#         'swversion': '1.0',
#         'type': 'CLIPGenericStatus',
#         'uniqueid': 'WA0001'},
#  '3': {'config': {'on': True, 'reachable': True},
#        'manufacturername': 'Philips',
#        'modelid': 'PHWA01',
#        'name': 'Dimmer Switch 2 SceneCycle',
#        'recycle': True,
#        'state': {'lastupdated': '2017-10-06T06:00:50', 'status': 0},
#        'swversion': '1.0',
#        'type': 'CLIPGenericStatus',
#        'uniqueid': 'WA0001'},
#  '4': {'config': {'alert': 'none',
#                   'battery': 100,
#                   'ledindication': False,
#                   'on': True,
#                   'pending': [],
#                   'reachable': True,
#                   'usertest': False},
#        'manufacturername': 'Philips',
#        'modelid': 'SML001',
#        'name': 'Hue temperature sensor 1',
#        'state': {'lastupdated': '2017-10-06T06:59:12', 'temperature': 1744},
#        'swupdate': {'lastinstall': None, 'state': 'noupdates'},
#        'swversion': '6.1.0.18912',
#        'type': 'ZLLTemperature',
#        'uniqueid': '00:17:88:01:02:00:af:28-02-0402'},
#  '5': {'config': {'alert': 'none',
#                   'battery': 100,
#                   'ledindication': False,
#                   'on': True,
#                   'pending': [],
#                   'reachable': True,
#                   'sensitivity': 2,
#                   'sensitivitymax': 2,
#                   'usertest': False},
#        'manufacturername': 'Philips',
#        'modelid': 'SML001',
#        'name': 'Hall Sensor',
#        'state': {'lastupdated': '2017-10-06T06:02:47', 'presence': False},
#        'swupdate': {'lastinstall': None, 'state': 'noupdates'},
#        'swversion': '6.1.0.18912',
#        'type': 'ZLLPresence',
#        'uniqueid': '00:17:88:01:02:00:af:28-02-0406'},
#  '6': {'config': {'alert': 'none',
#                   'battery': 100,
#                   'ledindication': False,
#                   'on': True,
#                   'pending': [],
#                   'reachable': True,
#                   'tholddark': 16000,
#                   'tholdoffset': 7000,
#                   'usertest': False},
#        'manufacturername': 'Philips',
#        'modelid': 'SML001',
#        'name': 'Hue ambient light sensor 1',
#        'state': {'dark': True,
#                  'daylight': False,
#                  'lastupdated': '2017-10-06T06:57:42',
#                  'lightlevel': 3433},
#        'swupdate': {'lastinstall': None, 'state': 'noupdates'},
#        'swversion': '6.1.0.18912',
#        'type': 'ZLLLightLevel',
#        'uniqueid': '00:17:88:01:02:00:af:28-02-0400'},
#  '7': {'config': {'on': True, 'reachable': True},
#        'manufacturername': 'Philips',
#        'modelid': 'PHA_STATE',
#        'name': 'MotionSensor 5.Companion',
#        'recycle': True,
#        'state': {'lastupdated': '2017-10-06T06:03:32', 'status': 0},
#        'swversion': '1.0',
#        'type': 'CLIPGenericStatus',
#        'uniqueid': 'MotionSensor 5.Companion'},
#  '8': {'config': {'alert': 'none',
#                   'battery': 100,
#                   'ledindication': False,
#                   'on': True,
#                   'pending': [],
#                   'reachable': True,
#                   'usertest': False},
#        'manufacturername': 'Philips',
#        'modelid': 'SML001',
#        'name': 'Hue temperature sensor 2',
#        'state': {'lastupdated': '2017-10-06T06:54:52', 'temperature': 1904},
#        'swupdate': {'lastinstall': None, 'state': 'noupdates'},
#        'swversion': '6.1.0.18912',
#        'type': 'ZLLTemperature',
#        'uniqueid': '00:17:88:01:02:00:b5:ce-02-0402'},
#  '9': {'config': {'alert': 'none',
#                   'battery': 100,
#                   'ledindication': False,
#                   'on': True,
#                   'pending': [],
#                   'reachable': True,
#                   'sensitivity': 2,
#                   'sensitivitymax': 2,
#                   'usertest': False},
#        'manufacturername': 'Philips',
#        'modelid': 'SML001',
#        'name': 'Bedroom sensor',
#        'state': {'lastupdated': '2017-10-06T06:00:54', 'presence': False},
#        'swupdate': {'lastinstall': None, 'state': 'noupdates'},
#        'swversion': '6.1.0.18912',
#        'type': 'ZLLPresence',
#        'uniqueid': '00:17:88:01:02:00:b5:ce-02-0406'}}
# True

# %% [markdown]
# Lets save the data for convenience.

# %%
save_response(response)
# Out:
# True

# %%
data = parse_hue_api_response(response)

# %%
data
# Out:
# {'1e-02': {'last_updated': ['2017-10-05', '21:35:48'],
#   'model': 'RWL021',
#   'name': 'Living room remote',
#   'state': '4_hold'},
#  '28-02': {'light_level': 3433,
#   'model': 'SML001',
#   'name': 'Hall motion Sensor',
#   'state': 'off',
#   'temperature': 17.44},
#  '9c-02': {'last_updated': ['2017-10-04', '06:04:54'],
#   'model': 'RWL021',
#   'name': 'Hall remote',
#   'state': '1_hold'},
#  'Geofence': {'model': 'Geofence', 'name': 'Robins iPhone', 'state': 'on'},
#  'ce-02': {'light_level': 10014,
#   'model': 'SML001',
#   'name': 'Bedroom motion sensor',
#   'state': 'off',
#   'temperature': 19.04},
#  'dc-02': {'last_updated': ['2017-10-06', '06:00:40'],
#   'model': 'RWL021',
#   'name': 'Remote bedroom',
#   'state': '4_click'}}
